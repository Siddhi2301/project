# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [24,35,46,57,68,78,89,90]
b = [12,23,34,45,56,67,79,80]
c = [13,21,32,43,54,65,76,87]

# %% [markdown]
# ## Line plot

# %%
plt.title("Line Plot")
plt.xlabel("a")
plt.ylabel("b")
plt.xticks(range(1,101,5))
plt.yticks(range(1,101,5))
plt.plot(a, b, marker = 'o', mfc = 'red', ms = 3, ls = '--');
plt.grid()

# %%
plt.title("Line plot")
plt.xlabel("b")
plt.ylabel("c")
plt.xticks(range(1,101,5))
plt.yticks(range(1,101,5))
plt.plot(b,c, marker = 'o', mfc = 'black', ms = 3, ls = 'dotted');
plt.grid()

# %%
plt.title("Line Plot")
plt.xlabel("a")
plt.ylabel("b")
plt.xticks(range(1,101,5))
plt.yticks(range(1,101,5))
plt.plot(a, b, marker = 'o', mfc = 'red', ms = 3, ls = 'dotted')
plt.plot(b, c, marker = 'o', mfc = 'black', ms = 3, ls = 'dotted')
plt.grid();

# %%
#subplot

# %%
plt.figure(figsize = (16, 8))
plt.subplot(2,3,1)
plt.title("Line Plot")
plt.xlabel("a")
plt.ylabel("b")
plt.xticks(range(1,101,5))
plt.yticks(range(1,101,5))
plt.plot(a, b, marker = 'o', mfc = 'red', ms = 3, ls = '--');
plt.grid()

plt.subplot(2,3,2)
plt.title("Line plot")
plt.xlabel("b")
plt.ylabel("c")
plt.xticks(range(1,101,5))
plt.yticks(range(1,101,5))
plt.plot(b,c, marker = 'o', mfc = 'black', ms = 3, ls = 'dotted');
plt.grid()

# %% [markdown]
# ## Bar plot

# %%
plt.xticks(range(1,101,5))
plt.yticks(range(1,101,5))
plt.bar(a, b);

# %%
course = ['Java','Python','R','C','ML','DBMS']
students = [58,95,37,52,73,77]

# %%
plt.title("Student Enrollment")
plt.xlabel("Courses")
plt.ylabel("No. of Students")
plt.yticks(range(1,101,5))
plt.bar(course, students, width = 0.5,color = 'grey', edgecolor = 'black', linewidth = 2);

# %%
import pandas as pd

# %%
df = pd.read_csv("Social_Network_Ads.csv")

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.scatter(df["Age"],df["EstimatedSalary"], c = df["Purchased"]);
df["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %% [markdown]
# ## Pie chart

# %%
color = ['Orange', 'lightYellow', 'Pink', 'Skyblue','purple','lightgreen']
plt.pie(students, labels = course, autopct = '%.f%%', shadow = True, labeldistance = 1.2, startangle = 90, explode = [0.4,0
                                                                                                                      ,0,0,0,0],
       colors = color);

# %%
plt.figure(figsize = (18,9))
plt.subplot(2,3,1)
plt.title("Line Plot")
plt.xlabel("a")
plt.ylabel("b")
plt.xticks(range(1,101,5))
plt.yticks(range(1,101,5))
plt.plot(a, b, marker = 'o', mfc = 'red', ms = 3, ls = 'dotted')
plt.plot(b, c, marker = 'o', mfc = 'black', ms = 3, ls = 'dotted')
plt.grid();


plt.subplot(2,3,2)
plt.title("Student Enrollment")
plt.xlabel("Courses")
plt.ylabel("No. of Students")
plt.yticks(range(0,100,5))
plt.bar(course, students, width = 0.005,color = 'grey', edgecolor = 'black', linewidth = 2);


plt.subplot(2,3,3)
plt.scatter(df["Age"],df["EstimatedSalary"], c = df["Purchased"]);


plt.subplot(2,3,4)
plt.pie(students, labels = course, autopct = '%.f%%', shadow = True, labeldistance = 1.2, startangle = 90, explode = [0.4,0
                                                                                                                      ,0,0,0,0],
       colors = color);
plt.savefig("My plot")

# %% [markdown]
# ## Box plot

# %%
marks = [45,67,69,74,53,65,56,67,99] 
plt.boxplot(marks);
q3 = np.percentile(marks,75)
q1 = np.percentile(marks,25)
iqr = q3 - q1

# %%
ub = q3 + (1.5 * iqr)
lb = q1 - (1.5 * iqr)
ub , lb
# Out:
# (88.5, 36.5)

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# joint plot
sns.jointplot(x = "sepal_length",y = "sepal_width",data = df,hue = "species");
# Out:
# C:\Users\siddhi\OneDrive\Documents\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\siddhi\OneDrive\Documents\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# pair plot
sns.pairplot(df, hue = "species")
# Out:
# C:\Users\siddhi\OneDrive\Documents\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\siddhi\OneDrive\Documents\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\siddhi\OneDrive\Documents\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
